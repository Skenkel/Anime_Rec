# %% [markdown]
# # Anime_Rec  (Hipster Variation)
# ## Live Demo Code

# %%
# !nvidia-smi
# Out:
# Mon Sep  4 18:14:09 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.69                 Driver Version: 384.69                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:04:00.0 Off |                  N/A |
# | 25%   52C    P0    69W / 250W |     10MiB / 11170MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from tqdm import tqdm
import mal_scraper
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
import mal_scraper
from tqdm import tqdm

# %%
import numpy as np
from keras import backend as K
from keras.layers import Input, Embedding, merge
import keras.layers
from keras.regularizers import l2, l1
from keras.layers.core import Flatten, Dense, Dropout, Lambda
from keras.models import Sequential, Model
from keras.optimizers import SGD, RMSprop, Adam
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
#import pydotplus as pydot 
#import graphviz
from keras.utils import plot_model
from sklearn.metrics import mean_absolute_error
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Pre-Loading Data

# %%
knownscores  = pd.read_csv('mal_scores_train_nonzero_v2.csv')
known_no_scores= pd.read_csv('mal_scores_train_zero.csv')
anime_avgs = np.load('anime_avgs.npy').item()
anime_names = pd.read_csv('Data/animeinfo3.csv').set_index('animeid')['name'].to_dict()
review_lf_numbers = pd.read_csv('lf_sim_animeid.csv',index_col='Unnamed: 0')
user_review_numbers = pd.read_csv('user_review_scaled_prod.csv',index_col='Unnamed: 0')
review_nlp_numbers = pd.read_csv('reviewnlpsim_animeid.csv',index_col='Unnamed: 0')

# %%
n_users = 229756
n_animes = 12826

# %%
userid2idx=np.load("user.npy").item()
animeid2idx=np.load("anime.npy").item()
anime_rev_dict=np.load("anime_rev_number.npy").item()

# %% [markdown]
# ## Set Hyper-parameters

# %%
n_highest_rated_shows= 7
k_nearest_shows = 7
t_highest_predicted_score=10
l_max_reviews = 3500

# %%
user_to_rec=input("Mal Username to check") # we ask the wat user we are lookingat
# Out:
# Mal Username to checkTheBaronVK

# %%
user_to_rec
# Out:
# 'TheBaronVK'

# %%
user_scores = knownscores[knownscores['userid']==user_to_rec]

# %%
userratinglist2 = []
if user_scores.shape[0]==0: # This means the user doesn't exist in our dataset and we need to scrape him. 
    reviewdict = {'userid':user_to_rec,'name':user_to_rec,'index':user_to_rec}
    useranime = mal_scraper.get_user_anime_list(user_to_rec)
    if useranime is None:
        print('User Has Not reviewed enough anime') # TODO Add seed shows
        pass
    else:
         for animeiter in range(len(useranime)):
            reviewdict = {'name':user_to_rec,'index':user_to_rec}
            reviewdict['unkey']= str(useranime[animeiter]['id_ref'])+str(user_to_rec)
            statusval = useranime[animeiter]['consumption_status'].value
            #userdict[animeid] = usertest[animenum]['id_ref']
            reviewdict['animescore'] =useranime[animeiter]['score']
            #userdict[animestart] =useranime[animeiter]['start_date']
            #userdict[animefinished] =useranime[animeiter]['finished_date']
            reviewdict['animeid'] =  str(useranime[animeiter]['id_ref'])
            reviewdict['status']= statusval
            userratinglist2.append(reviewdict)
    user_data= pd.DataFrame(userratinglist2) # this is the user's 0 and nonzero scores
    user_data['score']=user_data['animescore'] #standardize the column names
    user_scores=user_data[user_data['score']!=0] # scores
    user_zeroes =user_data[user_data['score']==0] #zero scores
    user_zeroes['animeid']=user_zeroes['animeid'].astype(int)
    useravg= user_scores['score'].mean()
    print(user_scores.head())
    user_scores['score_usr_scaled']=user_scores['score']-useravg
    print(user_scores.head())
    user_scores['animeid']=user_scores['animeid'].astype(int)
    user_scores['animeavg']= user_scores.animeid.map(anime_avgs)
    print(user_scores.head())
    user_scores['score_anime_scaled']=user_scores['score']-user_scores['animeavg']
    print(user_scores.head())
else:
    user_zeroes=known_no_scores[known_no_scores['userid']==user_to_rec]
# Out:
# ERROR:root:Unable to parse the date text "06-28-15" from an anime list
# ERROR:root:Unable to parse the date text "01-13-15" from an anime list
# ERROR:root:Unable to parse the date text "06-14-15" from an anime list
# ERROR:root:Unable to parse the date text "06-14-15" from an anime list
# ERROR:root:Unable to parse the date text "12-21-14" from an anime list
# ERROR:root:Unable to parse the date text "07-22-14" from an anime list
# ERROR:root:Unable to parse the date text "09-20-14" from an anime list
# ERROR:root:Unable to parse the date text "06-14-15" from an anime list
# ERROR:root:Unable to parse the date text "06-14-15" from an anime list
# ERROR:root:Unable to parse the date text "07-22-14" from an anime list
# ERROR:root:Unable to parse the date text "07-22-14" from an anime list
# ERROR:root:Unable to parse the date text "06-26-15" from an anime list
# ERROR:root:Unable to parse the date text "12-28-14" from an anime list
# ERROR:root:Unable to parse the date text "12-15-14" from an anime list
# ERROR:root:Unable to parse the date text "12-15-14" from an anime list
# ERROR:root:Unable to parse the date text "12-15-14" from an anime list
# ERROR:root:Unable to parse the date text "06-14-15" from an anime list
# ERROR:root:Unable to parse the date text "07-22-14" from an anime list
# ERROR:root:Unable to parse the date text "06-14-15" from an anime list
# ERROR:root:Unable to parse the date text "07-22-14" from an anime list
# ERROR:root:Unable to parse the date text "09-28-14" from an anime list
# ERROR:root:Unable to parse the date text "07-22-14" from an anime list
# ERROR:root:Unable to parse the date text "07-22-14" from an anime list
# ERROR:root:Unable to parse the date text "07-22-14" from an anime list
# ERROR:root:Unable to parse the date text "06-14-15" from an anime list
# ERROR:root:Unable to parse the date text "12-15-14" from an anime list
# ERROR:root:Unable to parse the date text "12-21-14" from an anime list
# ERROR:root:Unable to parse the date text "07-22-14" from an anime list
# ERROR:root:Unable to parse the date text "07-22-14" from an anime list
# ERROR:root:Unable to parse the date text "12-21-14" from an anime list
# ERROR:root:Unable to parse the date text "09-20-14" from an anime list
# ERROR:root:Unable to parse the date text "06-14-15" from an anime list
# ERROR:root:Unable to parse the date text "12-28-14" from an anime list
# ERROR:root:Unable to parse the date text "06-14-15" from an anime list
# ERROR:root:Unable to parse the date text "09-28-14" from an anime list
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    animeid  animescore       index        name     status            unkey  \
# 1     5342           7  TheBaronVK  TheBaronVK  CONSUMING   5342TheBaronVK
# 24    2605          10  TheBaronVK  TheBaronVK  CONSUMING   2605TheBaronVK
# 35   22199           8  TheBaronVK  TheBaronVK  COMPLETED  22199TheBaronVK
# 36      47           8  TheBaronVK  TheBaronVK  COMPLETED     47TheBaronVK
# 42   11111          10  TheBaronVK  TheBaronVK  COMPLETED  11111TheBaronVK
#
#     score
# 1       7
# 24     10
# 35      8
# 36      8
# 42     10
#    animeid  animescore       index        name     status            unkey  \
# 1     5342           7  TheBaronVK  TheBaronVK  CONSUMING   5342TheBaronVK
# 24    2605          10  TheBaronVK  TheBaronVK  CONSUMING   2605TheBaronVK
# 35   22199           8  TheBaronVK  TheBaronVK  COMPLETED  22199TheBaronVK
# 36      47           8  TheBaronVK  TheBaronVK  COMPLETED     47TheBaronVK
# 42   11111          10  TheBaronVK  TheBaronVK  COMPLETED  11111TheBaronVK
#
#     score  score_usr_scaled
# 1       7         -1.294643
# 24     10          1.705357
# 35      8         -0.294643
# 36      8         -0.294643
# 42     10          1.705357
#     animeid  animescore       index        name     status            unkey  \
# 1      5342           7  TheBaronVK  TheBaronVK  CONSUMING   5342TheBaronVK
# 24     2605          10  TheBaronVK  TheBaronVK  CONSUMING   2605TheBaronVK
# 35    22199           8  TheBaronVK  TheBaronVK  COMPLETED  22199TheBaronVK
# 36       47           8  TheBaronVK  TheBaronVK  COMPLETED     47TheBaronVK
# 42    11111          10  TheBaronVK  TheBaronVK  COMPLETED  11111TheBaronVK
#
#     score  score_usr_scaled  animeavg
# 1       7         -1.294643  7.055316
# 24     10          1.705357  7.987908
# 35      8         -0.294643  7.819367
# 36      8         -0.294643  8.183783
# 42     10          1.705357  7.847948
#     animeid  animescore       index        name     status            unkey  \
# 1      5342           7  TheBaronVK  TheBaronVK  CONSUMING   5342TheBaronVK
# 24     2605          10  TheBaronVK  TheBaronVK  CONSUMING   2605TheBaronVK
# 35    22199           8  TheBaronVK  TheBaronVK  COMPLETED  22199TheBaronVK
# 36       47           8  TheBaronVK  TheBaronVK  COMPLETED     47TheBaronVK
# 42    11111          10  TheBaronVK  TheBaronVK  COMPLETED  11111TheBaronVK
#
#     score  score_usr_scaled  animeavg  score_anime_scaled
# 1       7         -1.294643  7.055316           -0.055316
# 24     10          1.705357  7.987908            2.012092
# 35      8         -0.294643  7.819367            0.180633
# 36      8         -0.294643  8.183783           -0.183783
# 42     10          1.705357  7.847948            2.152052
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
possiblerecs=[]
#user_review_numbers = pd.read_csv('user_review_scaled_prod.csv',index_col='Unnamed: 0')
seedshows = set(user_scores.sort_values('score_usr_scaled',ascending=False)[:n_highest_rated_shows].animeid.values).union(set(user_scores.sort_values('score_anime_scaled',ascending=False)[:n_highest_rated_shows].animeid.values))

# %%
print("seed shows are:")
for rec in seedshows:
    print(anime_names[rec])
# Out:
# seed shows are:
# Toradora!
# Kore wa Zombie Desu ka? of the Dead
# Another
# Kore wa Zombie Desu ka?
# Mahou Shoujo Madoka★Magica Movie 2: Eien no Monogatari
# Sayonara Zetsubou Sensei
# Boogiepop wa Warawanai: Boogiepop Phantom
# Bakemonogatari
# Fullmetal Alchemist: Brotherhood
# Mahou Shoujo Madoka★Magica
# Suzumiya Haruhi no Yuuutsu (2009)

# %%
possiblerecs1=[]
for show in seedshows:
    topn =list(user_review_numbers.loc[:,str(show)].sort_values(ascending=False)[1:k_nearest_shows+1].index)
    print(show)
    possiblerecs1 = possiblerecs1+topn
    #print(type(show))
# Out:
# 4224
# 10790
# 11111
# 8841
# 11979
# 2605
# 369
# 5081
# 5114
# 9756
# 4382

# %%
len(possiblerecs1)#so now we have one third of the target shows to check.
# Out:
# 77

# %%
#review_nlp_numbers = pd.read_csv('reviewnlpsim_animeid.csv',index_col='Unnamed: 0')

# %%
review_nlp_numbers.head()
# Out:
#               1     32772         6         7         8        15        16  \
# 1      1.000000  0.772273  0.961916  0.958079  0.789438  0.937363  0.940282
# 32772  0.772273  1.000000  0.768938  0.743720  0.684533  0.798572  0.755860
# 6      0.961916  0.768938  1.000000  0.937337  0.792106  0.948547  0.933387
# 7      0.958079  0.743720  0.937337  1.000000  0.767137  0.910258  0.932606
# 8      0.789438  0.684533  0.792106  0.767137  1.000000  0.780716  0.774188
#
#              17        18        19    ...        25157     25159     25161  \
# 1      0.920310  0.902537  0.970917    ...     0.908150  0.934710  0.834914
# 32772  0.741147  0.745097  0.771846    ...     0.767707  0.756733  0.652148
# 6      0.926542  0.901927  0.976784    ...     0.910146  0.931709  0.839640
# 7      0.892298  0.883138  0.944207    ...     0.896787  0.931441  0.827226
# 8      0.761989  0.726089  0.802190    ...     0.762219  0.775014  0.668251
#
#           25183     25241     25271     25283     25285     25303     25313
# 1      0.969773  0.467217  0.365232  0.934109  0.425164  0.550415  0.646103
# 32772  0.781312  0.440492  0.387374  0.800241  0.427720  0.424690  0.552193
# 6      0.958035  0.476516  0.350941  0.927069  0.433980  0.522717  0.619298
# 7      0.961775  0.439031  0.351537  0.927716  0.439281  0.527624  0.625555
# 8      0.789861  0.378482  0.322515  0.785225  0.351967  0.465397  0.517582
#
# [5 rows x 6476 columns]

# %%
possiblerecs2 = []
for show in seedshows:
    try:
        topk =list(review_nlp_numbers.loc[:,str(show)].sort_values(ascending=False)[1:k_nearest_shows+1].index)
        possiblerecs2 = possiblerecs2+topk
    except:
        continue
    #print(type(show))

# %%
#review_lf_numbers = pd.read_csv('lf_sim_animeid.csv',index_col='Unnamed: 0')

# %%
possiblerecs3 = []
for show in seedshows:
    try:
        topk =list(review_lf_numbers.loc[:,str(show)].sort_values(ascending=False)[1:k_nearest_shows+1].index)
        possiblerecs3 = possiblerecs3+topk
    except:
        continue
    #print(type(show))

# %%
user_known_anime = list(user_scores.animeid.values)+ list(user_zeroes.animeid.values)

# %%
possiblerecs1=[anime for anime in possiblerecs1 if anime not in user_known_anime ]
possiblerecs2=[anime for anime in possiblerecs2 if anime not in user_known_anime ]
possiblerecs3=[anime for anime in possiblerecs3 if anime not in user_known_anime ]
possiblerecs = possiblerecs1+possiblerecs2+possiblerecs3

# %%
possiblerecs= list(set(possiblerecs))

# %%
possiblerecs= list(set(possiblerecs))

# %%
len(possiblerecs)
# Out:
# 108

# %%
print("Possible recs are:")
for rec in possiblerecs:
    print(anime_names[rec])
# Out:
# Possible recs are:
# Busou Renkin
# Kyoukai no Kanata Movie: I'll Be Here - Mirai-hen
# Kantai Collection: KanColle
# Haiyore! Nyaruko-san
# Texhnolyze
# Fairy Tail (2014)
# Good Morning Call
# Ghost Hunt
# Gabriel DropOut Specials
# Kizumonogatari I: Tekketsu-hen
# Fairy Tail
# D-Frag!
# Ore no Imouto ga Konnani Kawaii Wake ga Nai
# Mobile Police Patlabor 2: The Movie
# Kore wa Zombie Desu ka? of the Dead OVA
# Clannad: After Story
# Shimoneta to Iu Gainen ga Sonzai Shinai Taikutsu na Sekai
# Panty & Stocking with Garterbelt
# Ansatsu Kyoushitsu (TV) 2nd Season: Kagaijugyou-hen
# Yojouhan Shinwa Taikei
# Hundred
# Kaiba
# Rosario to Vampire Capu2
# Clannad
# Fruits Basket
# Neko Machi
# K
# Cross Ange: Tenshi to Ryuu no Rondo
# Shinryaku!? Ika Musume
# Kimi ga Nozomu Eien
# Zoku Sayonara Zetsubou Sensei
# Zero no Tsukaima
# Kennosuke-sama
# Escha & Logy no Atelier: Tasogare no Sora no Renkinjutsushi
# Nogizaka Haruka no Himitsu: Finale
# ef: A Tale of Melodies.
# Ao no Exorcist
# Baka to Test to Shoukanjuu
# Baccano!
# Danganronpa: Kibou no Gakuen to Zetsubou no Koukousei The Animation
# Princess Tutu
# Flip Flappers
# Sora no Otoshimono: Forte
# Date A Live II
# Date A Live
# Elfen Lied
# FLCL
# Sayonara Zetsubou Sensei Special
# Cardcaptor Sakura
# Zan Sayonara Zetsubou Sensei
# Genei wo Kakeru Taiyou
# Million Doll
# Aimai Elegy
# Dakara Boku wa, H ga Dekinai.
# Goku Sayonara Zetsubou Sensei
# Bleach
# Mnemosyne: Mnemosyne no Musume-tachi
# Ore no Nounai Sentakushi ga, Gakuen Love Comedy wo Zenryoku de Jama Shiteiru
# Working'!!
# Zero no Tsukaima: Futatsuki no Kishi
# Hunter x Hunter (2011)
# Steins;Gate Movie: Fuka Ryouiki no Déjà vu
# Kami nomi zo Shiru Sekai: Megami-hen
# Mousou Dairinin
# Baka to Test to Shoukanjuu Ni!
# Sora no Otoshimono
# Charlotte
# Nekomonogatari: Kuro
# Nikutai Ten'i
# Angel Beats!: Another Epilogue
# Naruto: Shippuuden Movie 5 - Blood Prison
# Lucky☆Star
# Joshikousei: Girl's High
# Fate/stay night
# Kekkai Sensen
# Jiok
# Hentai Ouji to Warawanai Neko.
# Mahou Shoujo Lyrical Nanoha: The Movie 1st
# Mirai Nikki (TV)
# Zan Sayonara Zetsubou Sensei Bangaichi
# Angel Beats!
# Tonari no Kaibutsu-kun
# Ookami to Koushinryou
# Kimi ni Todoke
# Ore no Kanojo to Osananajimi ga Shuraba Sugiru
# Ookamikakushi
# Ore no Imouto ga Konnani Kawaii Wake ga Nai. Specials
# Yuuki Yuuna wa Yuusha de Aru
# Owarimonogatari 2nd Season
# Another: The Other - Inga
# Hidan no Aria
# Gokukoku no Brynhildr
# Kimi ni Todoke 2nd Season
# Sakurasou no Pet na Kanojo
# Shingeki no Kyojin Picture Drama
# Nisekoi
# Tengen Toppa Gurren Lagann
# Sukitte Ii na yo.
# Kore wa Zombie Desu ka? OVA
# Mawaru Penguindrum
# Golden Time
# Ao Haru Ride
# Yoshimoto Muchikko Monogatari
# Fate/kaleid liner Prisma☆Illya
# Yonimo Osoroshii Grimm Douwa
# Kanon (2006)
# Suzumiya Haruhi-chan no Yuuutsu
# Death Note

# %%
print("Possible recs1(User Scores) are:")
for rec in set(possiblerecs1):
    print(anime_names[rec])
# Out:
# Possible recs1(User Scores) are:
# Zan Sayonara Zetsubou Sensei Bangaichi
# Goku Sayonara Zetsubou Sensei
# Angel Beats!
# Suzumiya Haruhi-chan no Yuuutsu
# Texhnolyze
# Zoku Sayonara Zetsubou Sensei
# Ookamikakushi
# Ore no Imouto ga Konnani Kawaii Wake ga Nai. Specials
# Kizumonogatari I: Tekketsu-hen
# Another: The Other - Inga
# Hunter x Hunter (2011)
# Sakurasou no Pet na Kanojo
# Mousou Dairinin
# Baka to Test to Shoukanjuu Ni!
# Sora no Otoshimono
# Mobile Police Patlabor 2: The Movie
# Nekomonogatari: Kuro
# Kore wa Zombie Desu ka? of the Dead OVA
# Clannad: After Story
# Sora no Otoshimono: Forte
# Lucky☆Star
# Kore wa Zombie Desu ka? OVA
# Elfen Lied
# Sayonara Zetsubou Sensei Special
# Zan Sayonara Zetsubou Sensei
# Yojouhan Shinwa Taikei
# Yoshimoto Muchikko Monogatari
# Yonimo Osoroshii Grimm Douwa
# Jiok
# Mirai Nikki (TV)
# Neko Machi
# Death Note

# %%
print("Possible recs2(Tf-IDF) are:")
for rec in set(possiblerecs2):
    print(anime_names[rec])
# Out:
# Possible recs2(Tf-IDF) are:
# K
# Kyoukai no Kanata Movie: I'll Be Here - Mirai-hen
# Haiyore! Nyaruko-san
# Mnemosyne: Mnemosyne no Musume-tachi
# Tonari no Kaibutsu-kun
# Angel Beats!
# Ore no Nounai Sentakushi ga, Gakuen Love Comedy wo Zenryoku de Jama Shiteiru
# Ookami to Koushinryou
# Clannad
# Fairy Tail (2014)
# Kimi ni Todoke
# Ghost Hunt
# Zero no Tsukaima
# Yuuki Yuuna wa Yuusha de Aru
# Hidan no Aria
# Gokukoku no Brynhildr
# Steins;Gate Movie: Fuka Ryouiki no Déjà vu
# Hentai Ouji to Warawanai Neko.
# Sakurasou no Pet na Kanojo
# Mousou Dairinin
# Charlotte
# Baka to Test to Shoukanjuu
# Baccano!
# Nisekoi
# Princess Tutu
# Flip Flappers
# Date A Live II
# Panty & Stocking with Garterbelt
# Date A Live
# Mawaru Penguindrum
# Elfen Lied
# FLCL
# Golden Time
# Cardcaptor Sakura
# Ao Haru Ride
# Fate/kaleid liner Prisma☆Illya
# Genei wo Kakeru Taiyou
# Kaiba
# Kekkai Sensen
# Fruits Basket
# Mahou Shoujo Lyrical Nanoha: The Movie 1st
# Kanon (2006)

# %%
print("Possible recs3(Hidden Factors) are:")
for rec in set(possiblerecs3):
    print(anime_names[rec])
# Out:
# Possible recs3(Hidden Factors) are:
# Busou Renkin
# Cross Ange: Tenshi to Ryuu no Rondo
# Dakara Boku wa, H ga Dekinai.
# Kantai Collection: KanColle
# Shinryaku!? Ika Musume
# Bleach
# Tonari no Kaibutsu-kun
# Kimi ga Nozomu Eien
# Working'!!
# Ore no Kanojo to Osananajimi ga Shuraba Sugiru
# Good Morning Call
# Gabriel DropOut Specials
# Zero no Tsukaima
# Kennosuke-sama
# Fairy Tail
# Escha & Logy no Atelier: Tasogare no Sora no Renkinjutsushi
# Zero no Tsukaima: Futatsuki no Kishi
# Owarimonogatari 2nd Season
# Nogizaka Haruka no Himitsu: Finale
# ef: A Tale of Melodies.
# Kimi ni Todoke 2nd Season
# D-Frag!
# Ao no Exorcist
# Shingeki no Kyojin Picture Drama
# Kami nomi zo Shiru Sekai: Megami-hen
# Ore no Imouto ga Konnani Kawaii Wake ga Nai
# Charlotte
# Nikutai Ten'i
# Danganronpa: Kibou no Gakuen to Zetsubou no Koukousei The Animation
# Nisekoi
# Tengen Toppa Gurren Lagann
# Sukitte Ii na yo.
# Angel Beats!: Another Epilogue
# Shimoneta to Iu Gainen ga Sonzai Shinai Taikutsu na Sekai
# Naruto: Shippuuden Movie 5 - Blood Prison
# Ansatsu Kyoushitsu (TV) 2nd Season: Kagaijugyou-hen
# Joshikousei: Girl's High
# Elfen Lied
# Fate/stay night
# Hundred
# Ao Haru Ride
# Fate/kaleid liner Prisma☆Illya
# Million Doll
# Rosario to Vampire Capu2
# Hentai Ouji to Warawanai Neko.
# Mirai Nikki (TV)
# Aimai Elegy

# %%
ratings_score_test = pd.read_csv('mal_scores_test_nonzero_v2.csv')

# %%
ratings_score_test.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1  animeid  \
# 0           0             0              13              13      889
# 1           1             1              16              16    28907
# 2           2             2             233             233    21185
# 3           3             3             243             243    18507
# 4           4             4             248             248    15059
#
#    animescore            index             name     status  \
# 0           9   SeinfeldHentai   SeinfeldHentai  COMPLETED
# 1           9   SeinfeldHentai   SeinfeldHentai  COMPLETED
# 2           7  OPERATIONiDROID  OPERATIONiDROID  COMPLETED
# 3           9  OPERATIONiDROID  OPERATIONiDROID  COMPLETED
# 4           8  OPERATIONiDROID  OPERATIONiDROID  COMPLETED
#
#                   unkey           userid  score   useravg  animeavg  \
# 0     889SeinfeldHentai   SeinfeldHentai      9  9.111111  8.157417
# 1   28907SeinfeldHentai   SeinfeldHentai      9  9.111111  7.894818
# 2  21185OPERATIONiDROID  OPERATIONiDROID      7  7.767857  7.921898
# 3  18507OPERATIONiDROID  OPERATIONiDROID      9  7.767857  7.631896
# 4  15059OPERATIONiDROID  OPERATIONiDROID      8  7.767857  8.219309
#
#    score_anime_scaled  score_usr_scaled  user_rev_count  anime_rev_count
# 0            0.842583         -0.111111               9            18397
# 1            1.105182         -0.111111               9            15497
# 2           -0.921898         -0.767857              56             3329
# 3            1.368104          1.232143              56            16786
# 4           -0.219309          0.232143              56             1564

# %%
recs=pd.DataFrame(possiblerecs, columns=['animeid'])

# %%
recs['userid']=user_to_rec

# %%
recs['animescore']=0
recs['score_anime_scaled']=0
recs['score_usr_scaled']=0

# %%
#recs.head()

# %%
#type(userid2idx)

# %%
#userid2idx

# %%
recs['user_id_emb'] = len(userid2idx)+2

# %%
user_scores['anime_id_emb']= user_scores.animeid.apply(lambda x: animeid2idx[x])
user_scores['user_id_emb']= len(userid2idx)+1
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
user_scores['anime_id_emb']= user_scores.animeid.apply(lambda x: animeid2idx[x])
recs['anime_id_emb'] = recs.animeid.apply(lambda x: animeid2idx[x])
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
n_factors =28

# %%
def embedding_input_anime1(name, n_in, n_out, reg):
    inp = Input(shape=(1,), dtype='int64', name=name)
    return inp, Embedding(n_in, n_out, input_length=1, W_regularizer=l2(reg),name='Embed_Anime_Hidden_Factors')(inp)
def embedding_input_user1(name, n_in, n_out, reg):
    inp = Input(shape=(1,), dtype='int64', name=name)
    return inp, Embedding(n_in, n_out, input_length=1, W_regularizer=l2(reg),name='Embed_User_Hidden_Factors')(inp)

user_in1, u1 = embedding_input_user1('user_id_in', n_users+15, n_factors, 0)
u1.trainable=True
anime_in1, a1 = embedding_input_anime1('anime_id_in', n_animes, n_factors, 0)
a1.trainable=False
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: UserWarning: Update your `Embedding` call to the Keras 2 API: `Embedding(229771, 28, input_length=1, name="Embed_User_Hidden_Factors", embeddings_regularizer=<keras.reg...)`
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Embedding` call to the Keras 2 API: `Embedding(12826, 28, input_length=1, name="Embed_Anime_Hidden_Factors", embeddings_regularizer=<keras.reg...)`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# nn1, It is given no modifications for status. It is predicting score
x = merge([u1, a1], mode='concat', name='All_Factors_on_one_layer')
x.trainable=False
x = Flatten()(x)
x.trainable=False
x = Dense(70, activation='relu',name='Random_HF_Interactions')(x)
x.trainable=False
x = Dropout(0.55,name='Prevent_overfit2')(x)
x.trainable=False
x = Dense(16, activation='relu',name='Random_HF_Interactions2')(x)
x.trainable=False
x = Dropout(0.1, name='Prevent_overfit')(x)
x.trainable=False
x = Dense(1,name='Final_Interactions')(x)
x.trainable=False
nn1 = Model([user_in1, anime_in1], x)
nn1.compile(Adam(0.001), loss='mse')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)

# %%
nn1.load_weights('nn_score_weights_hip.h5',by_name=True)

# %%
# !nvidia-smi
# Out:
# Mon Sep  4 18:30:17 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.69                 Driver Version: 384.69                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:04:00.0 Off |                  N/A |
# | 20%   43C    P2    59W / 250W |  10691MiB / 11170MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
nn1.fit([user_scores.user_id_emb, user_scores.anime_id_emb], user_scores.score, epochs=9)
# Out:
# Epoch 1/9
# 112/112 [==============================] - 0s - loss: 2.3775
# Epoch 2/9
# 112/112 [==============================] - 0s - loss: 2.0032
# Epoch 3/9
# 112/112 [==============================] - 0s - loss: 1.7488
# Epoch 4/9
# 112/112 [==============================] - 0s - loss: 1.5679
# Epoch 5/9
# 112/112 [==============================] - 0s - loss: 1.4098
# Epoch 6/9
# 112/112 [==============================] - 0s - loss: 1.3587
# Epoch 7/9
# 112/112 [==============================] - 0s - loss: 1.2382
# Epoch 8/9
# 112/112 [==============================] - 0s - loss: 1.1706
# Epoch 9/9
# 112/112 [==============================] - 0s - loss: 1.1352

# %%
recs['score']=nn1.predict([recs.user_id_emb, recs.anime_id_emb])

# %%
recs.head()
# Out:
#    animeid      userid  animescore  score_anime_scaled  score_usr_scaled  \
# 0     1536  TheBaronVK           0                   0                 0
# 1    28675  TheBaronVK           0                   0                 0
# 2    21511  TheBaronVK           0                   0                 0
# 3    11785  TheBaronVK           0                   0                 0
# 4       26  TheBaronVK           0                   0                 0
#
#    user_id_emb  anime_id_emb     score
# 0       230964          1394  8.287192
# 1       230964          9734  9.176086
# 2       230964          8444  7.968464
# 3       230964          6624  8.156238
# 4       230964            16  8.916574

# %%
recs.sort_values('score',ascending=False)
# Out:
#      animeid      userid  animescore  score_anime_scaled  score_usr_scaled  \
# 88     35247  TheBaronVK           0                   0                 0
# 19      7785  TheBaronVK           0                   0                 0
# 21      3701  TheBaronVK           0                   0                 0
# 9       9260  TheBaronVK           0                   0                 0
# 1      28675  TheBaronVK           0                   0                 0
# 99     10721  TheBaronVK           0                   0                 0
# 35      4789  TheBaronVK           0                   0                 0
# 40       721  TheBaronVK           0                   0                 0
# 79      7044  TheBaronVK           0                   0                 0
# 54      4872  TheBaronVK           0                   0                 0
# 77      4985  TheBaronVK           0                   0                 0
# 30      3228  TheBaronVK           0                   0                 0
# 49      6377  TheBaronVK           0                   0                 0
# 13      1096  TheBaronVK           0                   0                 0
# 58     10521  TheBaronVK           0                   0                 0
# 4         26  TheBaronVK           0                   0                 0
# 47     10469  TheBaronVK           0                   0                 0
# 63       323  TheBaronVK           0                   0                 0
# 41     32979  TheBaronVK           0                   0                 0
# 8      34855  TheBaronVK           0                   0                 0
# 7       1571  TheBaronVK           0                   0                 0
# 104     4085  TheBaronVK           0                   0                 0
# 18     32863  TheBaronVK           0                   0                 0
# 87     25519  TheBaronVK           0                   0                 0
# 106     5118  TheBaronVK           0                   0                 0
# 56      3342  TheBaronVK           0                   0                 0
# 28     10378  TheBaronVK           0                   0                 0
# 89     11701  TheBaronVK           0                   0                 0
# 69     10067  TheBaronVK           0                   0                 0
# 27     25731  TheBaronVK           0                   0                 0
# ..       ...         ...         ...                 ...               ...
# 59      1840  TheBaronVK           0                   0                 0
# 78     10620  TheBaronVK           0                   0                 0
# 73       356  TheBaronVK           0                   0                 0
# 24       120  TheBaronVK           0                   0                 0
# 65      5958  TheBaronVK           0                   0                 0
# 66     28999  TheBaronVK           0                   0                 0
# 67     15689  TheBaronVK           0                   0                 0
# 22      4214  TheBaronVK           0                   0                 0
# 55       269  TheBaronVK           0                   0                 0
# 64      8516  TheBaronVK           0                   0                 0
# 61     11577  TheBaronVK           0                   0                 0
# 74     24439  TheBaronVK           0                   0                 0
# 26     14467  TheBaronVK           0                   0                 0
# 76     15225  TheBaronVK           0                   0                 0
# 53     12549  TheBaronVK           0                   0                 0
# 57     19221  TheBaronVK           0                   0                 0
# 3      11785  TheBaronVK           0                   0                 0
# 86     18857  TheBaronVK           0                   0                 0
# 2      21511  TheBaronVK           0                   0                 0
# 50     17651  TheBaronVK           0                   0                 0
# 20     31338  TheBaronVK           0                   0                 0
# 94     19391  TheBaronVK           0                   0                 0
# 68      1359  TheBaronVK           0                   0                 0
# 32     18603  TheBaronVK           0                   0                 0
# 85      7079  TheBaronVK           0                   0                 0
# 6       1056  TheBaronVK           0                   0                 0
# 33     21167  TheBaronVK           0                   0                 0
# 102    12781  TheBaronVK           0                   0                 0
# 72       863  TheBaronVK           0                   0                 0
# 51     29941  TheBaronVK           0                   0                 0
#
#      user_id_emb  anime_id_emb      score
# 88        230964         12518  10.177941
# 19        230964          5158   9.956967
# 21        230964          3231   9.581819
# 9         230964          5688   9.520836
# 1         230964          9734   9.176086
# 99        230964          6346   9.079673
# 35        230964          3819   9.077748
# 40        230964           663   9.068547
# 79        230964          4882   9.057858
# 54        230964          3867   9.056766
# 77        230964          3909   9.047142
# 30        230964          2897   9.032084
# 49        230964          4573   9.026936
# 13        230964           996   9.009291
# 58        230964          6250   8.919762
# 4         230964            16   8.916574
# 47        230964          6226   8.904119
# 63        230964           299   8.904022
# 41        230964         11446   8.850731
# 8         230964         12318   8.752225
# 7         230964          1427   8.725715
# 104       230964          3490   8.701086
# 18        230964         11387   8.655310
# 87        230964          9272   8.547410
# 106       230964          3976   8.540010
# 56        230964          2972   8.534848
# 28        230964          6188   8.532765
# 89        230964          6594   8.512702
# 69        230964          6055   8.496552
# 27        230964          9306   8.479554
# ..           ...           ...        ...
# 59        230964          1676   8.169111
# 78        230964          6296   8.169111
# 73        230964           332   8.169111
# 24        230964            99   8.169111
# 65        230964          4396   8.169111
# 66        230964          9810   8.169111
# 67        230964          7304   8.169111
# 22        230964          3563   8.169111
# 55        230964           245   8.169111
# 64        230964          5410   8.169111
# 61        230964          6565   8.169111
# 74        230964          9077   8.169111
# 26        230964          7138   8.169111
# 76        230964          7242   8.169111
# 53        230964          6778   8.169111
# 57        230964          8020   8.169111
# 3         230964          6624   8.156238
# 86        230964          7960   7.997014
# 2         230964          8444   7.968464
# 50        230964          7701   7.780066
# 20        230964         10742   7.758849
# 94        230964          8049   7.743512
# 68        230964          1228   7.716935
# 32        230964          7910   7.708607
# 85        230964          4894   7.708331
# 6         230964           960   7.661717
# 33        230964          8385   7.590058
# 102       230964          6828   7.571808
# 72        230964           779   7.532118
# 51        230964         10108   7.225435
#
# [108 rows x 8 columns]

# %%
def embedding_input_anime22(name, n_in, n_out, reg):
    inp = Input(shape=(1,), dtype='int64', name=name)
    return inp, Embedding(n_in, n_out, input_length=1, W_regularizer=l2(reg),name='Embed_Anime_Hidden_Factors')(inp)
def embedding_input_user22(name, n_in, n_out, reg):
    inp = Input(shape=(1,), dtype='int64', name=name)
    return inp, Embedding(n_in, n_out, input_length=1, W_regularizer=l2(reg),name='Embed_User_Hidden_Factors')(inp)

user_in22, u22 = embedding_input_user22('user_id_in', n_users+15, n_factors, 0)
u22.trainable=True
anime_in22, a22 = embedding_input_anime22('anime_id_in', n_animes, n_factors, 0)
a22.trainable=False
# nn22, It is only given complete. Trying to predict usr scaled score. 
x = merge([u22, a22], mode='concat', name='All_Factors_on_one_layer')
x.trainable=False
x = Flatten()(x)
x.trainable=False
x = Dense(70, activation='relu',name='Random_HF_Interactions')(x)
x.trainable=False
x = Dropout(0.55,name='Prevent_overfit2')(x)
x.trainable=False
x = Dense(16, activation='relu',name='Random_HF_Interactions2')(x)
x.trainable=False
x = Dropout(0.1, name='Prevent_overfit')(x)
x.trainable=False
x = Dense(1,name='Final_Interactions')(x)
x.trainable=False
nn22 = Model([user_in22, anime_in22], x)
nn22.compile(Adam(0.001), loss='mse')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: UserWarning: Update your `Embedding` call to the Keras 2 API: `Embedding(229771, 28, input_length=1, name="Embed_User_Hidden_Factors", embeddings_regularizer=<keras.reg...)`
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Embedding` call to the Keras 2 API: `Embedding(12826, 28, input_length=1, name="Embed_Anime_Hidden_Factors", embeddings_regularizer=<keras.reg...)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:13: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   del sys.path[0]
# /usr/local/lib/python3.5/dist-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)

# %%
nn22.load_weights('nn_score_usr_weights_hip.h5',by_name=True)

# %%
nn22.fit([user_scores.user_id_emb, user_scores.anime_id_emb], user_scores.score_usr_scaled, epochs=9)
# Out:
# Epoch 1/9
# 112/112 [==============================] - 0s - loss: 1.3846
# Epoch 2/9
# 112/112 [==============================] - 0s - loss: 1.4084
# Epoch 3/9
# 112/112 [==============================] - 0s - loss: 1.3073
# Epoch 4/9
# 112/112 [==============================] - 0s - loss: 1.2778
# Epoch 5/9
# 112/112 [==============================] - 0s - loss: 1.2157
# Epoch 6/9
# 112/112 [==============================] - 0s - loss: 1.1798
# Epoch 7/9
# 112/112 [==============================] - 0s - loss: 1.1745
# Epoch 8/9
# 112/112 [==============================] - 0s - loss: 1.1720
# Epoch 9/9
# 112/112 [==============================] - 0s - loss: 1.1634

# %%
recs['score_usr_scaled']=nn22.predict([recs.user_id_emb, recs.anime_id_emb])

# %%
def embedding_input_anime23(name, n_in, n_out, reg):
    inp = Input(shape=(1,), dtype='int64', name=name)
    return inp, Embedding(n_in, n_out, input_length=1, W_regularizer=l2(reg),name='Embed_Anime_Hidden_Factors')(inp)
def embedding_input_user23(name, n_in, n_out, reg):
    inp = Input(shape=(1,), dtype='int64', name=name)
    return inp, Embedding(n_in, n_out, input_length=1, W_regularizer=l2(reg),name='Embed_User_Hidden_Factors')(inp)

user_in23, u23 = embedding_input_user23('user_id_in', n_users+15, n_factors, 0)
u23.trainable=True
anime_in23, a23 = embedding_input_anime23('anime_id_in', n_animes, n_factors, 0)
a23.trainable=False
# nn22, It is only given complete. Trying to predict usr scaled score. 
x = merge([u23, a23], mode='concat', name='All_Factors_on_one_layer')
x.trainable=False
x = Flatten()(x)
x.trainable=False
x = Dense(70, activation='relu',name='Random_HF_Interactions')(x)
x.trainable=False
x = Dropout(0.55,name='Prevent_overfit2')(x)
x.trainable=False
x = Dense(16, activation='relu',name='Random_HF_Interactions2')(x)
x.trainable=False
x = Dropout(0.1, name='Prevent_overfit')(x)
x.trainable=False
x = Dense(1,name='Final_Interactions')(x)
x.trainable=False
nn23 = Model([user_in23, anime_in23], x)
nn23.compile(Adam(0.001), loss='mse')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: UserWarning: Update your `Embedding` call to the Keras 2 API: `Embedding(229771, 28, input_length=1, name="Embed_User_Hidden_Factors", embeddings_regularizer=<keras.reg...)`
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Embedding` call to the Keras 2 API: `Embedding(12826, 28, input_length=1, name="Embed_Anime_Hidden_Factors", embeddings_regularizer=<keras.reg...)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:13: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   del sys.path[0]
# /usr/local/lib/python3.5/dist-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)

# %%
nn23.load_weights('nn_score_anime_weights_hip.h5',by_name=True)

# %%
nn23.fit([user_scores.user_id_emb, user_scores.anime_id_emb], user_scores.score_usr_scaled, epochs=9)
# Out:
# Epoch 1/9
# 112/112 [==============================] - 0s - loss: 1.3189
# Epoch 2/9
# 112/112 [==============================] - 0s - loss: 1.3159
# Epoch 3/9
# 112/112 [==============================] - 0s - loss: 1.3255
# Epoch 4/9
# 112/112 [==============================] - 0s - loss: 1.3156
# Epoch 5/9
# 112/112 [==============================] - 0s - loss: 1.2744
# Epoch 6/9
# 112/112 [==============================] - 0s - loss: 1.2668
# Epoch 7/9
# 112/112 [==============================] - 0s - loss: 1.2435
# Epoch 8/9
# 112/112 [==============================] - 0s - loss: 1.2372
# Epoch 9/9
# 112/112 [==============================] - 0s - loss: 2.0353

# %%
recs['score_anime_scaled']=nn23.predict([recs.user_id_emb, recs.anime_id_emb])

# %%
recs['anime_rev_count']= recs.animeid.map(anime_rev_dict)

# %%
recs=recs[recs['anime_rev_count']<l_max_reviews]

# %%
recs.sort_values('score_usr_scaled',ascending=False).head(t_highest_predicted_score)
# Out:
#     animeid      userid  animescore  score_anime_scaled  score_usr_scaled  \
# 88    35247  TheBaronVK           0            0.432729          1.241478
# 21     3701  TheBaronVK           0            0.489274          0.955230
# 79     7044  TheBaronVK           0            0.416817          0.681413
# 77     4985  TheBaronVK           0            0.199897          0.635642
# 30     3228  TheBaronVK           0            0.300844          0.635589
# 54     4872  TheBaronVK           0            0.318647          0.621449
# 49     6377  TheBaronVK           0            0.350733          0.609077
# 47    10469  TheBaronVK           0            0.410003          0.544837
# 41    32979  TheBaronVK           0            0.363935          0.500468
# 8     34855  TheBaronVK           0            0.043705          0.412009
#
#     user_id_emb  anime_id_emb      score  anime_rev_count
# 88       230964         12518  10.177941              422
# 21       230964          3231   9.581819             1711
# 79       230964          4882   9.057858              802
# 77       230964          3909   9.047142              852
# 30       230964          2897   9.032084             3100
# 54       230964          3867   9.056766             1655
# 49       230964          4573   9.026936             2031
# 47       230964          6226   8.904119              320
# 41       230964         11446   8.850731             2658
# 8        230964         12318   8.752225              617

# %%
recs.sort_values('score_anime_scaled',ascending=False).head(t_highest_predicted_score)
# Out:
#     animeid      userid  animescore  score_anime_scaled  score_usr_scaled  \
# 32    18603  TheBaronVK           0            0.654716         -0.803352
# 13     1096  TheBaronVK           0            0.518503         -0.225853
# 4        26  TheBaronVK           0            0.516500         -0.225975
# 21     3701  TheBaronVK           0            0.489274          0.955230
# 52    13053  TheBaronVK           0            0.473624         -0.074179
# 88    35247  TheBaronVK           0            0.432729          1.241478
# 79     7044  TheBaronVK           0            0.416817          0.681413
# 47    10469  TheBaronVK           0            0.410003          0.544837
# 41    32979  TheBaronVK           0            0.363935          0.500468
# 49     6377  TheBaronVK           0            0.350733          0.609077
#
#     user_id_emb  anime_id_emb      score  anime_rev_count
# 32       230964          7910   7.708607                8
# 13       230964           996   9.009291              521
# 4        230964            16   8.916574             2344
# 21       230964          3231   9.581819             1711
# 52       230964          6888   8.308313               72
# 88       230964         12518  10.177941              422
# 79       230964          4882   9.057858              802
# 47       230964          6226   8.904119              320
# 41       230964         11446   8.850731             2658
# 49       230964          4573   9.026936             2031

# %%
recs.sort_values('score',ascending=False).head(t_highest_predicted_score)
# Out:
#     animeid      userid  animescore  score_anime_scaled  score_usr_scaled  \
# 88    35247  TheBaronVK           0            0.432729          1.241478
# 21     3701  TheBaronVK           0            0.489274          0.955230
# 40      721  TheBaronVK           0            0.322037         -0.229326
# 79     7044  TheBaronVK           0            0.416817          0.681413
# 54     4872  TheBaronVK           0            0.318647          0.621449
# 77     4985  TheBaronVK           0            0.199897          0.635642
# 30     3228  TheBaronVK           0            0.300844          0.635589
# 49     6377  TheBaronVK           0            0.350733          0.609077
# 13     1096  TheBaronVK           0            0.518503         -0.225853
# 4        26  TheBaronVK           0            0.516500         -0.225975
#
#     user_id_emb  anime_id_emb      score  anime_rev_count
# 88       230964         12518  10.177941              422
# 21       230964          3231   9.581819             1711
# 40       230964           663   9.068547             3210
# 79       230964          4882   9.057858              802
# 54       230964          3867   9.056766             1655
# 77       230964          3909   9.047142              852
# 30       230964          2897   9.032084             3100
# 49       230964          4573   9.026936             2031
# 13       230964           996   9.009291              521
# 4        230964            16   8.916574             2344

# %%
score_user_preds =recs.sort_values('score_usr_scaled',ascending=False).head(t_highest_predicted_score)
score_preds =recs.sort_values('score',ascending=False).head(t_highest_predicted_score)
score_anime_preds =recs.sort_values('score_anime_scaled',ascending=False).head(t_highest_predicted_score)

# %%
print("Recommendations for score are:")
for rec in score_preds.animeid.values:
    print(anime_names[rec])
# Out:
# Recommendations for score are:
# Owarimonogatari 2nd Season
# Kaiba
# Princess Tutu
# Zan Sayonara Zetsubou Sensei Bangaichi
# Goku Sayonara Zetsubou Sensei
# Mahou Shoujo Lyrical Nanoha: The Movie 1st
# Zoku Sayonara Zetsubou Sensei
# Zan Sayonara Zetsubou Sensei
# Mobile Police Patlabor 2: The Movie
# Texhnolyze

# %%
print("Recommendations for  User_Scaled score are:")
for rec in score_user_preds.animeid.values:
    print(anime_names[rec])
# Out:
# Recommendations for  User_Scaled score are:
# Owarimonogatari 2nd Season
# Kaiba
# Zan Sayonara Zetsubou Sensei Bangaichi
# Mahou Shoujo Lyrical Nanoha: The Movie 1st
# Zoku Sayonara Zetsubou Sensei
# Goku Sayonara Zetsubou Sensei
# Zan Sayonara Zetsubou Sensei
# Sayonara Zetsubou Sensei Special
# Flip Flappers
# Gabriel DropOut Specials

# %%
print("Recommendations for  Anime_Scaled score are:")
for rec in score_anime_preds.animeid.values:
    print(anime_names[rec])
# Out:
# Recommendations for  Anime_Scaled score are:
# Kennosuke-sama
# Mobile Police Patlabor 2: The Movie
# Texhnolyze
# Kaiba
# Aimai Elegy
# Owarimonogatari 2nd Season
# Zan Sayonara Zetsubou Sensei Bangaichi
# Sayonara Zetsubou Sensei Special
# Flip Flappers
# Zan Sayonara Zetsubou Sensei
